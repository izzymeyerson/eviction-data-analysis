# %%
import sqlalchemy as sa
from sqlalchemy import text
import pandas as pd
from dotenv import load_dotenv
import os

load_dotenv()
ENGINE = sa.create_engine(os.environ.DATABASE_URL)

# %%
query = f"""
    SELECT * from marshal_evictions_17 limit 10
"""
df = pd.read_sql(text(query), con = ENGINE)

# %%
df
# Out:
#         boro courtindex docketnumber                          evictionaddress  \
# 0  MANHATTAN   60479/17        71116                     355 SOUTH END AVENUE
# 1  MANHATTAN   57548/17        72783                     355 SOUTH END AVENUE
# 2  MANHATTAN   74330/17        76597                     355 SOUTH END AVENUE
# 3  MANHATTAN   74334/17        76598                     375 SOUTH END AVENUE
# 4  MANHATTAN   66782/16         6106                     375 SOUTH END AVENUE
# 5  MANHATTAN   50411/17         9356                     375 SOUTH END AVENUE
# 6  MANHATTAN   68059/16         9628                     375 SOUTH END AVENUE
# 7  MANHATTAN   59510/17       469696                         325 N END AVENUE
# 8  MANHATTAN   64595/17         7931  225 RECTOR PLACE TWO TWENTY FIVE RECTOR
# 9  MANHATTAN   76472/16       462473                     200 NORTH END AVENUE
#
#    apt    zip             uniqueid executeddate marshalfirstname  \
# 0   6N  10280   60479/177111610280   2017-08-03            Henry
# 1  10G  10280   57548/177278310280   2017-09-12            Henry
# 2  22B  10280   74330/177659710280   2017-11-30            Henry
# 3  26F  10280   74334/177659810280   2017-11-30            Henry
# 4   8F  10280    66782/16610610280   2017-03-03           Edward
# 5  22U  10280    50411/17935610280   2017-05-03           Edward
# 6  24L  10280    68059/16962810280   2017-04-14           Edward
# 7  PHD  10282  59510/1746969610282   2017-07-05            Danny
# 8  22B  10280    64595/17793110280   2017-10-03           George
# 9  27B  10282  76472/1646247310282   2017-01-26            Danny
#
#   marshallastname evictiontype scheduledstatus  \
# 0           Daley  Residential       Scheduled
# 1           Daley  Residential       Scheduled
# 2           Daley  Residential       Scheduled
# 3           Daley  Residential       Scheduled
# 4           Guida  Residential       Scheduled
# 5           Guida  Residential       Scheduled
# 6           Guida  Residential       Scheduled
# 7        Weinheim  Residential       Scheduled
# 8     Essock, Jr.  Residential       Scheduled
# 9        Weinheim  Residential       Scheduled
#
#                            cleanedaddress1       lat       lng  \
# 0  355 SOUTH END AVENUE MANHATTAN NY 10280  40.71081 -74.01623
# 1  355 SOUTH END AVENUE MANHATTAN NY 10280  40.71081 -74.01623
# 2  355 SOUTH END AVENUE MANHATTAN NY 10280  40.71081 -74.01623
# 3  375 SOUTH END AVENUE MANHATTAN NY 10280  40.71093 -74.01617
# 4  375 SOUTH END AVENUE MANHATTAN NY 10280  40.71093 -74.01617
# 5  375 SOUTH END AVENUE MANHATTAN NY 10280  40.71093 -74.01617
# 6  375 SOUTH END AVENUE MANHATTAN NY 10280  40.71093 -74.01617
# 7      325 N END AVENUE MANHATTAN NY 10282  40.71696 -74.01498
# 8      225 RECTOR PLACE MANHATTAN NY 10280  40.70950 -74.01594
# 9  200 NORTH END AVENUE MANHATTAN NY 10282  40.71596 -74.01479
#
#               geocoder       cleanedaddress2         bbl
# 0  Bing via Excel tool  355 SOUTH END AVENUE  1000160100
# 1  Bing via Excel tool  355 SOUTH END AVENUE  1000160100
# 2  Bing via Excel tool  355 SOUTH END AVENUE  1000160100
# 3  Bing via Excel tool  375 SOUTH END AVENUE  1000160100
# 4  Bing via Excel tool  375 SOUTH END AVENUE  1000160100
# 5  Bing via Excel tool  375 SOUTH END AVENUE  1000160100
# 6  Bing via Excel tool  375 SOUTH END AVENUE  1000160100
# 7  Bing via Excel tool      325 N END AVENUE  1000160195
# 8  Bing via Excel tool      225 RECTOR PLACE  1000167515
# 9  Bing via Excel tool  200 NORTH END AVENUE  1000167520
